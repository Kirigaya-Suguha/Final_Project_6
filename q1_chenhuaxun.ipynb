# %% [markdown]
# **Step 1: Data Preparation**
#
#   1. **Download COVID-19 Data**
#
#       Fetch the dataset from OWID.
#
#   2. **Filter Data for China and the US**
#
#       Use the `location` column to extract data for `China` and `United States`. Focus on:
#         + `new_cases`
#         + `new_deaths`
#         + `stringency_index`
#
#   3. **Supplement with Policy Data**
#
#       + For China: Collect data on lockdowns, mass testing, and zero-COVID strategies.
#       + For the US: Collect data on federal/state-level measures, vaccination rollouts, and public health mandates.
#       + Use sources like government websites and the Oxford COVID-19 Government Response Tracker (OxCGRT).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load COVID-19 data
covid_data = pd.read_csv("owid-covid-data.csv")

# Filter for China, US, Singapore, India
countries = ["China", "United States", "Singapore", "India"]
df = covid_data[covid_data['location'].isin(countries)]

# Focus on relevant columns
df = df[["date", "location", "new_cases_per_million", "new_deaths_per_million", "stringency_index", "reproduction_rate",  "population", "new_cases_smoothed_per_million", "new_deaths_smoothed_per_million", "total_tests", "new_tests", "total_tests_per_thousand", "new_tests_per_thousand", "new_tests_smoothed", "new_tests_smoothed_per_thousand", ]]
df['date'] = pd.to_datetime(df['date'])

# # Rolling averages for new cases per million and deaths per million
# df['new_cases_7day_per_million'] = df.groupby('location')['new_cases_per_million'].transform(lambda x: x.rolling(7).mean())
# df['new_deaths_7day_per_million'] = df.groupby('location')['new_deaths_per_million'].transform(lambda x: x.rolling(7).mean())

custom_palette = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# Plot trends for new cases per million
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='date', y='new_cases_smoothed_per_million', hue='location', palette=custom_palette)
plt.title("7-Day Rolling Average of New Cases Per Million (China vs. US vs. Singapore vs. India)")
plt.xlabel("Date")
plt.ylabel("New Cases Per Million (7-day average)")
plt.legend(title="Country")
plt.show()

# Plot trends for new deaths per million
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='date', y='new_deaths_smoothed_per_million', hue='location', palette=custom_palette)
plt.title("7-Day Rolling Average of New Deaths Per Million (China vs. US vs. Singapore vs. India)")
plt.xlabel("Date")
plt.ylabel("New Deaths Per Million (7-day average)")
plt.legend(title="Country")
plt.show()

# %% [markdown]
# **Step 4: Advanced Integration of Policy Data**
#
# **1. Load and Merge Data**
#
#   + **COVID-19 Data:** Use the OWID dataset for cases and deaths.
#   + **Policy Data:** Use the `OxCGRT_compact_national_v1.csv` for `stringency_index` and relevant policy indicators.
#   + **Vaccination Data:** Use `OxCGRT_vaccines_full_national_v1.csv` for vaccination metrics like `total_vaccinations_per_hundred`.
#
# **Steps for Data Merging:**
#
#   1. **Filter and Align Dates:** Ensure the `date` columns in all datasets are in the same format (`YYYY-MM-DD`).
#   2. **Merge Datasets:** Use `location` and `date` as keys for merging OWID, policy, and vaccination data.
#   3. **Focus on Relevant Metrics: Extract:**
#       + COVID-19: `new_cases`, `new_deaths`
#       + Policies: `stringency_index`, key policy flags (e.g., school closures, workplace closures)
#       + Vaccination: `total_vaccinations_per_hundred`

# %%
# Load datasets
covid_data = pd.read_csv("owid-covid-data.csv", parse_dates=["date"])
policy_data = pd.read_csv("OxCGRT_compact_national_v1.csv", parse_dates=["Date"])
vaccination_data = pd.read_csv("OxCGRT_vaccines_full_national_v1.csv", parse_dates=["Date"])

# Filter for China and US
countries = ["China", "United States", "Singapore", "India"]
covid_data = covid_data[covid_data["location"].isin(countries)]
policy_data = policy_data[policy_data["CountryName"].isin(countries)]
vaccination_data = vaccination_data[vaccination_data["CountryName"].isin(countries)]

# Rename columns for consistency
policy_data.rename(columns={"Date": "date", "CountryName": "location"}, inplace=True)
vaccination_data.rename(columns={"Date": "date", "CountryName": "location"}, inplace=True)

# Merge datasets
merged_data = pd.merge(covid_data, policy_data, on=["location", "date"], how="inner")
merged_data = pd.merge(merged_data, vaccination_data, on=["location", "date"], how="inner")

# Focus on relevant columns
merged_data = merged_data[
    ["date", "location", "new_cases", "new_deaths", "new_cases_per_million", "new_deaths_per_million", "reproduction_rate", "total_tests", "new_tests", "total_tests_per_thousand", "new_tests_per_thousand", "new_tests_smoothed", "new_tests_smoothed_per_thousand", "stringency_index", "total_vaccinations_per_hundred", "C1M_School closing", "H2_Testing policy", "H3_Contact tracing", "H6M_Facial Coverings"]
]

# %% [markdown]
# **Step 5: Advanced Visualizations**
#
# **1. Timeline with Policy Annotations**
#
# Create line plots of `new_cases` and `new_deaths` over time, annotated with significant policy changes.
#
# Example (China's early lockdown and US vaccination campaign):

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 确保 'date' 列是 datetime 类型
merged_data['date'] = pd.to_datetime(merged_data['date'])

# 设定需要比较的国家
countries = ["China", "United States", "Singapore", "India"]

color_mapping = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# 绘制每百万人感染人数的曲线
plt.figure(figsize=(16, 8))
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    plt.plot(subset["date"], subset["new_cases_per_million"], color=color_mapping[country], label=f"{country} Cases per Million", alpha=0.7)

# 标记关键政策
plt.axvline(pd.Timestamp("2020-01-23"), color="red", linestyle="--", label="China: Wuhan Lockdown")
plt.axvline(pd.Timestamp("2021-01-01"), color="blue", linestyle="--", label="US: Vaccination Rollout")

# 添加标题和标签
plt.title("COVID-19 Cases Per Million with Key Policy Annotations (China, US, Singapore, India)")
plt.xlabel("Date")
plt.ylabel("New Cases Per Million")
plt.legend()

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt

# 选择你感兴趣的国家，比如 China 和 United States
for country in countries:
    country_data = merged_data[merged_data["location"] == country].set_index("date")
    country_data["stringency_index"].plot(label=country, figsize=(12, 6), color=color_mapping[country])

plt.title("Stringency Index Over Time (China vs. US vs. Singapore vs. India)")
plt.xlabel("Date")
plt.ylabel("Stringency Index")
plt.legend(title="Country")
plt.show()

# %% [markdown]
# **2. Policy Stringency vs. Cases/Deaths**
#
#   Scatter or line plot showing `stringency_index` against `new_cases`. Correlation can also be calculated:

# %%
sns.scatterplot(data=merged_data, x="stringency_index", y="new_cases_per_million", hue="location", palette=custom_palette, alpha=0.6)
plt.title("Stringency Index vs. New Cases (China vs. US vs. Singapore vs. India)")
plt.xlabel("Stringency Index")
plt.ylabel("New Cases")
plt.legend(title="Country")
plt.show()

# %% [markdown]
# **3. Comparative Metrics**
#
#   Use bar plots to compare total cases, deaths, and vaccination rates per million for both countries.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 筛选相关国家的数据
filtered_data = merged_data[merged_data["location"].isin(countries)]

# 按国家分组并计算所需的统计量
summary = filtered_data.groupby("location").agg({
    "new_cases_per_million": "sum",   # 累计每百万人新病例
    "new_deaths_per_million": "sum", # 累计每百万人新死亡
    "total_vaccinations_per_hundred": "max" # 最大的疫苗接种率
}).reset_index()

# 计算每百万人感染的总病例数和死亡数
summary["new_cases_per_million"] = summary.apply(
    lambda row: row["new_cases_per_million"] if row["location"] in countries else 0, axis=1
)

summary["new_deaths_per_million"] = summary.apply(
    lambda row: row["new_deaths_per_million"] if row["location"] in countries else 0, axis=1
)

# 创建一个包含三行一列的子图
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

# 绘制每百万人数据的条形图
summary.set_index("location")[["new_cases_per_million"]].plot(kind="bar", ax=axes[0], color="skyblue")
axes[0].set_title("New Cases Per Million (China, US, Singapore, India)")
axes[0].set_ylabel("New Cases Per Million")

summary.set_index("location")[["new_deaths_per_million"]].plot(kind="bar", ax=axes[1], color="salmon")
axes[1].set_title("New Deaths Per Million (China, US, Singapore, India)")
axes[1].set_ylabel("New Deaths Per Million")

summary.set_index("location")[["total_vaccinations_per_hundred"]].plot(kind="bar", ax=axes[2], color="lightgreen")
axes[2].set_title("Vaccinations Per Hundred People (China, US, Singapore, India)")
axes[2].set_ylabel("Vaccinations Per Hundred People")

# 调整布局，避免标题重叠
plt.tight_layout()
plt.show()

# %% [markdown]
# **4. Vaccination Impact**
#
#   Dual-axis plot of vaccination rates and new cases:

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))

# Plot new_cases_per_million
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax1.plot(subset["date"], subset["new_cases_per_million"], color=color_mapping[country], label=f"{country} Cases per Million", alpha=0.7)

# Plot vaccination rates
ax2 = ax1.twinx()
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax2.plot(subset["date"], subset["total_vaccinations_per_hundred"], color=color_mapping[country], label=f"{country} Vaccination Rate", linestyle="--")

ax1.set_title("Vaccination Rates and COVID-19 Trends (China vs. US)")
ax1.set_xlabel("Date")
ax1.set_ylabel("New Cases per Million")
ax2.set_ylabel("Vaccination Rate (%)")
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")
plt.show()

# %% [markdown]
# **Step 6: Key Metrics and Insights**
#
# **Statistical Analysis**
#
#   + Correlation between `stringency_index` and `new_cases/new_deaths` for both countries:

# %%
correlations = merged_data.groupby("location").apply(
    lambda x: x[["stringency_index", "new_deaths_per_million", "new_deaths_per_million"]].corr()
)
print(correlations)
# Out:
#                                       stringency_index  \
# location
# China         stringency_index                1.000000
#               new_deaths_per_million         -0.014785
#               new_deaths_per_million         -0.014785
# India         stringency_index                1.000000
#               new_deaths_per_million          0.142405
#               new_deaths_per_million          0.142405
# Singapore     stringency_index                1.000000
#               new_deaths_per_million         -0.037185
#               new_deaths_per_million         -0.037185
# United States stringency_index                1.000000
#               new_deaths_per_million          0.144222
#               new_deaths_per_million          0.144222
#
#                                       new_deaths_per_million  \
# location
# China         stringency_index                     -0.014785
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# India         stringency_index                      0.142405
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# Singapore     stringency_index                     -0.037185
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# United States stringency_index                      0.144222
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
#
#                                       new_deaths_per_million
# location
# China         stringency_index                     -0.014785
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# India         stringency_index                      0.142405
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# Singapore     stringency_index                     -0.037185
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# United States stringency_index                      0.144222
#               new_deaths_per_million                1.000000
#               new_deaths_per_million                1.000000
# D:\TEMP\ipykernel_14184\2029094700.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   correlations = merged_data.groupby("location").apply(

# %% [markdown]
# Insights:
#
#   + China:
#     - Strict early lockdown and Zero-COVID policies minimized cases and deaths but prolonged social restrictions.
#     - Vaccination rollout began later but was widespread.
#
#   + US:
#     - Delayed lockdown measures led to higher initial case counts.
#     - Vaccination campaigns dramatically reduced deaths during subsequent waves.
#     - Decentralized policies caused variation in outcomes across states.

# %% [markdown]
# 1. Advanced Visualizations
#
#   + **Heatmap of Stringency vs. Cases/Deaths Over Time**
#
#     Heatmaps can show how stringency levels correlate with COVID cases/deaths over time.

# %%
import seaborn as sns

# Pivot data
heatmap_data = merged_data.pivot_table(index="date", columns="location", values="stringency_index")

# Plot heatmap
plt.figure(figsize=(14, 6))
sns.heatmap(heatmap_data, cmap="coolwarm", cbar_kws={"label": "Stringency Index"})
plt.title("Stringency Index Over Time (China vs. US vs. Singapore vs. India)")
plt.xlabel("Country")
plt.ylabel("Date")
plt.show()

# %% [markdown]
#   + **Time-Series Decomposition**
#
#     Break down `new_cases` into trend, seasonality, and residual components to better understand temporal patterns.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Decompose for each country
china_data = merged_data[merged_data["location"] == "China"].set_index("date")
us_data = merged_data[merged_data["location"] == "United States"].set_index("date")
sg_data = merged_data[merged_data["location"] == "Singapore"].set_index("date")
India_data = merged_data[merged_data["location"] == "India"].set_index("date")

# Create subplots for each decomposition component
fig, axes = plt.subplots(3, 1, figsize=(16, 12))  # 3 rows, 1 column

# Decompose the data for each country
countries = [("China", china_data), ("United States", us_data), ("Singapore", sg_data), ("India", India_data)]
decompositions = {country: seasonal_decompose(data["new_cases_per_million"].fillna(0), model="additive", period=7) for country, data in countries}

# Plot trend for each country
for i, (country, decomposition) in enumerate(decompositions.items()):
    axes[0].plot(decomposition.trend, color=color_mapping[country], label=country)
axes[0].set_title('Trend Component of New Cases Per Million')
axes[0].set_ylabel('Trend')
axes[0].legend()

# Plot seasonal component for each country
for i, (country, decomposition) in enumerate(decompositions.items()):
    axes[1].plot(decomposition.seasonal, color=color_mapping[country], label=country)
axes[1].set_title('Seasonal Component of New Cases Per Million')
axes[1].set_ylabel('Seasonality')
axes[1].legend()

# Plot residual component for each country
for i, (country, decomposition) in enumerate(decompositions.items()):
    axes[2].plot(decomposition.resid, color=color_mapping[country], label=country)
axes[2].set_title('Residual Component of New Cases Per Million')
axes[2].set_ylabel('Residuals')
axes[2].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.1 学校关闭政策 vs 新增病例数

# %%
import matplotlib.pyplot as plt

countries = ["China", "United States", "Singapore", "India"]

color_mapping = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# 创建图形，两个子图
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True)

# 绘制新增病例数（new_cases_per_million）在第一个子图上
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax1.plot(subset["date"], subset["new_cases_per_million"], color=color_mapping[country], label=f"{country} Cases per Million", alpha=0.7)

ax1.set_ylabel("New Cases per Million")
ax1.set_title("New Cases per Million vs. Time")
ax1.grid(True)

# 绘制学校关闭政策（C1M_School closing）在第二个子图上
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax2.plot(subset["date"], subset["C1M_School closing"], color=color_mapping[country], label=f"{country} School Closing Policy", linestyle="--", alpha=0.7)

ax2.set_xlabel("Date")
ax2.set_ylabel("School Closing Policy (0-3 Scale)")
ax2.set_title("School Closing Policy vs. Time")
ax2.grid(True)

# 调整图例位置，避免遮挡线条
fig.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Countries")

# 显示图形
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis 1.1
#
# 1. China and India saw stricter school closures during the peaks, potentially contributing to reduced spread during those times.
# 2. The U.S. had more inconsistent school closures, with waves of opening and closing that might reflect the uneven nature of the pandemic control efforts across states.
# 3. Singapore, with its consistent but less strict policies, seemed to maintain lower case numbers compared to the others, suggesting that early and ongoing pandemic management might have contributed to lower transmission.
#
# This visualization suggests that school closures were one of the many factors influencing the trends in COVID-19 cases, with stricter policies potentially correlating with lower case numbers during certain periods.

# %% [markdown]
# 1.2 口罩政策 vs 新增病例数

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data' is already available and contains the relevant data
# Countries to analyze
countries = ["China", "United States", "Singapore", "India"]

# Define color mapping for countries
color_mapping = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# Create the figure and the first axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True)

# Plot new confirmed cases per million
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax1.plot(subset["date"], subset["new_cases_per_million"], color=color_mapping[country], label=f"{country} New Cases per Million", alpha=0.7)

# Set first y-axis labels and title
ax1.set_ylabel("New Cases per Million")
ax1.set_title("New Cases per Million vs. Time")
ax1.grid(True)

# Plot mask wearing policy (H6M_Facial Coverings)
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax2.plot(subset["date"], subset["H6M_Facial Coverings"], color=color_mapping[country], label=f"{country} Mask Wearing Policy", alpha=0.7, linestyle="--")

ax2.set_xlabel("Date")
ax2.set_ylabel("Mask Wearing Policy (0-3 Scale)")
ax2.set_title("Mask Wearing Policy vs. Time")
ax2.grid(True)

fig.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Countries")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis 1.2
#
# Surprisingly, there is no significant correlation between H6M_Facial Coverings and new_cases_per_million. Although the spike in new_cases_per_million in the US and India in January 2022 seems to coincide with a reduction in H6M_Facial Coverings from late 2021 to early 2022, China also reduced its H6M_Facial Coverings without seeing a significant increase in new_cases_per_million. At the same time, Singapore did not reduce its H6M_Facial Coverings yet still faced a spike in new_cases_per_million. This suggests that mask policies may not have effectively prevented the spread of the virus. Throughout the pandemic, China consistently had the lowest H6M_Facial Coverings levels (2.0), yet it remained one of the countries with the fewest new_cases_per_million. This could indicate that masks did not have the expected effect and may have only served as a psychological comfort.

# %% [markdown]
# 1.3 基本传染数 vs. 接触者追踪

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data' is already available and contains the relevant data
# Countries to analyze
countries = ["China", "United States", "Singapore", "India"]

# Define color mapping for countries
color_mapping = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# Create the figure and the first axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True)

# Plot reproduction rate (R value)
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax1.plot(subset["date"], subset["reproduction_rate"], color=color_mapping[country], label=f"{country} Reproduction Rate (R)", alpha=0.7)

# Set first y-axis labels and title
ax1.set_ylabel("Reproduction Rate (R)")
ax1.set_title("Reproduction Rate vs. Time")
ax1.grid(True)

# Plot contact tracing policy (H3_Contact tracing)
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax2.plot(subset["date"], subset["H3_Contact tracing"], color=color_mapping[country], label=f"{country} Contact Tracing Policy", alpha=0.7, linestyle="--")

ax2.set_xlabel("Date")
ax2.set_ylabel("Contact Tracing Policy (0-3 Scale)")
ax2.set_title("Contact Tracing Policy vs. Time")
ax2.grid(True)

fig.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Countries")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis 1.3
#
# Singapore and China implemented very strict Contact Tracing policies (level 2) right after the pandemic began. India later followed with a generally strict Contact Tracing policy. However, compared to the relatively lenient policies (level 1) in the United States, the Reproduction Rate did not perform better. But we cannot directly conclude that the Contact Tracing policy had no effect. In fact, we need to consider population and land area, as contact is related to these factors. The United States is large and sparsely populated, so the probability of contact is lower, and there is less spatial mobility. While China and India have large land areas, their populations are numerous, which increases the likelihood of contact. Furthermore, China's infrastructure and public transportation are more developed than India’s, leading to higher population mobility. Singapore, though small in population, has a small land area, convenient public transportation, and high population mobility, which also leads to a higher probability of contact. From this perspective, the Reproduction Rate in China and Singapore is more difficult to control than in the U.S. and India. However, after implementing very strict Contact Tracing policies, the Reproduction Rate in China and Singapore is almost on par with that of the U.S. and India. Therefore, we can conclude that strict Contact Tracing is effective in reducing the basic reproduction number.

# %% [markdown]
# 5.1 新增检测量 vs 检测政策

# %%
import matplotlib.pyplot as plt

# Assuming 'merged_data' is already available and contains the relevant data
# Countries to analyze
countries = ["China", "United States", "Singapore", "India"]

# Define color mapping for countries
color_mapping = {
    "China": "red",
    "United States": "blue",
    "Singapore": "green",
    "India": "orange"
}

# Create the figure and the first axis
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 12), sharex=True)

# Plot new tests smooth per thousand
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax1.plot(subset["date"], subset["new_tests_smoothed_per_thousand"], color=color_mapping[country], label=f"{country} New Tests Smooth per Thousand", alpha=0.7)

# Set first y-axis labels and title
ax1.set_ylabel("New Tests Smooth per Thousand")
ax1.set_title("New Tests Smooth per Thousand vs. Time")
ax1.grid(True)

# Plot testing policy (H2_Testing policy)
for country in countries:
    subset = merged_data[merged_data["location"] == country]
    ax2.plot(subset["date"], subset["H2_Testing policy"], color=color_mapping[country], label=f"{country} Testing Policy", alpha=0.7, linestyle="--")

ax2.set_xlabel("Date")
ax2.set_ylabel("Testing Policy (0-4 Scale)")
ax2.set_title("Testing Policy vs. Time")
ax2.grid(True)

fig.legend(loc="upper left", bbox_to_anchor=(1, 1), title="Countries")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis 5.1
#
# Combined with the analysis of new_cases_per_million, Singapore only started recording new_tests_smoothed_per_thousand in early 2022. This may have been because the absolute number of infections was not significant before, so there was no emphasis on maintaining records for new_tests_smoothed_per_thousand. However, in early 2022, when new_cases_per_million surged to over 20,000, Singapore conducted a large number of new tests in a short period of time. China, on the other hand, implemented the strictest H2_Testing policy very early, which resulted in China's new_tests_smoothed_per_thousand remaining stable at a certain level thereafter. Across all countries, the testing rates are relatively low, indicating that the H2_Testing policy does not represent universal nucleic acid testing, but may instead refer to more accurate antigen tests. India's H2_Testing policy was relatively lenient, so the testing rate was also low. In the United States, the testing rate increased before January 2022 as the H2_Testing policy became stricter, but after the policy remained unchanged, the testing rate fluctuated. This suggests that the impact of the H2_Testing policy on new_tests_smoothed_per_thousand varies by country. While the effect is almost imperceptible in the U.S., Singapore, and India, it is significant in China, which may be due to differences in social systems. China is a socialist country, while the U.S., Singapore, and India are capitalist countries.
